# %% [markdown]
# # 使用 pandas 进行数据可视化

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
matplotlib.__version__
pd.options.display.mpl_style ='default'

# %% [markdown]
#   pd.options.display.mpl_style ='default' 用来产生更多好看的图

# %%
ts = pd.Series(randn(1000,),index = pd.date_range('1/1/2000',periods = 1000))
ts.shape
ts
# Out:
# 2000-01-01   -1.110266
# 2000-01-02   -2.117597
# 2000-01-03    0.353056
# 2000-01-04   -0.994302
# 2000-01-05    1.367321
# 2000-01-06    1.513617
# 2000-01-07    0.721478
# 2000-01-08   -1.282175
# 2000-01-09   -1.141088
# 2000-01-10    1.023113
# 2000-01-11   -1.289446
# 2000-01-12    0.317653
# 2000-01-13    1.729333
# 2000-01-14    2.542291
# 2000-01-15    0.349259
# ...
# 2002-09-12   -0.712598
# 2002-09-13   -0.625183
# 2002-09-14   -0.011056
# 2002-09-15   -0.416075
# 2002-09-16   -0.215481
# 2002-09-17   -1.387374
# 2002-09-18   -0.123841
# 2002-09-19    0.310522
# 2002-09-20    2.136085
# 2002-09-21   -0.774709
# 2002-09-22    1.118981
# 2002-09-23    0.201882
# 2002-09-24    0.140003
# 2002-09-25    0.998699
# 2002-09-26    0.403778
# Freq: D, Length: 1000

# %% [markdown]
# 这后面是什么意思？pd.Series()以为数据，并包括labels

# %% [markdown]
# index = pd.date_range('1/1/2000',periods = 1000)是什么意思

# %%
ts = ts.cumsum()
ts.plot()

# %% [markdown]
# ts.cumsum 按照要求的轴返回累积值，等会试下其他的,
# 好像是没有用的。

# %% [markdown]
# 但是这个数据只能是一维的，无法是二维的，
# 并且这个数据怎样和周期想作用

# %%
ts.plot()

# %%
df = pd.DataFrame(randn(1000,4),index=ts.index,columns=list('ABCD'))

# %%
df = df.cumsum()
df.plot()
# Out:
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %%
plt.figure()
df.plot()

# %% [markdown]
# 上面的两个有什么区别

# %%
df3 = pd.DataFrame(randn(1000,2),columns=['B','C']).cumsum()

# %% [markdown]
# 什么意思 colunns 是什么意思

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %% [markdown]
# list 是分开排列的意思

# %%
df3.plot(x ='A',y ='B',legend='gj')

# %% [markdown]
# 这里 legnd 没有用，并且y label也没有用

# %%
plt.figure()
df.ix[5].plot(kind='bar')

# %% [markdown]
# plt.ix[5]是什么意思

# %%
df4 = pd.DataFrame(randn(8,3),columns=list('ABC'))
df4.plot(kind ='bar')

# %% [markdown]
# 这里为什么要使columns ？

# %%
df4.plot(kind = 'barh')

# %% [markdown]
# 这个表示横线

# %%
a = randn(1000)
a.shape
# Out:
# (1000,)

# %%
df4.plot(kind = 'hist',bins = 10)

# %% [markdown]
# 使用横着的图

# %%
df4.plot(kind = 'hist',orientation ='horizontal', bins = 10)

# %%
plt.figure()
df.diff().hist()
# Out:
# array([[<matplotlib.axes.AxesSubplot object at 0x7fe4936aa9d0>,
#         <matplotlib.axes.AxesSubplot object at 0x7fe493f6d9d0>],
#        [<matplotlib.axes.AxesSubplot object at 0x7fe493862290>,
#         <matplotlib.axes.AxesSubplot object at 0x7fe494142350>]], dtype=object)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1246: UserWarning: findfont: Could not match :family=Bitstream Vera Sans:style=normal:variant=normal:weight=normal:stretch=normal:size=x-large. Returning /usr/share/matplotlib/mpl-data/fonts/ttf/cmb10.ttf
#   UserWarning)

# %% [markdown]
# 这个表示什么意思？

# %%
df['A'].diff().hist()

# %% [markdown]
# 'A'表示图像A吗？

# %%
df = pd.DataFrame(rand(10,4),columns=list('ABCD'))
df.plot(kind ='area')

# %% [markdown]
# ## scatter plot

# %%
df = pd.DataFrame(rand(50,4),columns=list('abcd'))
df.plot(kind ='scatter',x ='a',y='c')

# %%
ax = df.plot(kind ='scatter',x ='a',y ='b',color = 'DarkBlue',label ='Group 1')
ax = df.plot(kind ='scatter',x ='c',y ='d',color = 'DarkGreen',label ='Group 2')

# %% [markdown]
# columuns 和 labe 有什么区别

# %%
df.plot(kind ='scatter',x='a',y='b',s=120)

# %%
df.plot(kind='scatter', x='a', y='b', c='c', s=120);

# %% [markdown]
# 这里的'c'是什么意思，加入坐标

# %% [markdown]
# ## Hexagonal Bin Plot

# %% [markdown]
# ## Pie Plot

# %%
series = pd.Series(2*rand(4),index=list('abbc'),name ='series')
series.plot(kind ='pie',autopct = '%.2f',figsize=(8,8))

# %% [markdown]
# 这个df 为什么是矩阵，而现实的又是另外一个样子？

# %%
from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(randn(100,4),columns= list ('abcd'))
scatter_matrix(df,alpha=0.4,figsize=(10,10),diagonal = 'kde')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-685a73b53242> in <module>()
#       1 from pandas.tools.plotting import scatter_matrix
# ----> 2 df = pd.DataFrame(randn(100,4),columns= list ('abcd'))
#       3 scatter_matrix(df,alpha=0.4,figsize=(10,10),diagonal = 'kde')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Density Plot

# %%
ser = pd.Series(rand(100))
ser.plot(kind ='kde')

# %% [markdown]
# ## Andrews Curves

# %% [markdown]
# 可以画多个图线，使用傅里叶级数，什么意思

# %%
from pandas import  read_csv
from pandas.tools.plotting import andrews_curves
#data = read_csv('data/iris.data')

# %% [markdown]
# ## Lag Plot

# %% [markdown]
# 检测数据是否是随机数据？

# %%
from pandas.tools.plotting import lag_plot
plt.figure()
data = pd.Series(0.1*uniform(1000)+0.9*np.sin(np.linspace(-99*np.pi,99*np.pi,num=1000)))
lag_plot(data)

# %% [raw]
# 测试一个均匀数据

# %%
import numpy as np 
from pandas import DataFrame
import matplotlib.pyplot as plt

Index= ['aaa', 'bbb', 'ccc', 'ddd', 'eee']
Cols = ['A', 'B', 'C', 'D']
df = DataFrame(abs(np.random.randn(5, 4)), index=Index, columns=Cols)

plt.pcolor(df)
plt.yticks(np.arange(0.5, len(df.index), 1), df.index)
plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns)
plt.show()

# %%
p4d = pd.Panel4D(randn(2, 2, 5, 4),
   ....:       labels=['Label1','Label2'],
   ....:       items=['Item1', 'Item2'],
   ....:       major_axis=pd.date_range('1/1/2000', periods=5),
   ....:       minor_axis=['A', 'B', 'C', 'D'])
p4d
# Out:
# <class 'pandas.core.panelnd.Panel4D'>
# Dimensions: 2 (labels) x 2 (items) x 5 (major_axis) x 4 (minor_axis)
# Labels axis: Label1 to Label2
# Items axis: Item1 to Item2
# Major_axis axis: 2000-01-01 00:00:00 to 2000-01-05 00:00:00
# Minor_axis axis: A to D

# %% [markdown]
# 这个是什么意思
