# %% [markdown]
# # [Maximum Likelihood Estimation](http://nbviewer.ipython.org/github/rlabbe/Python-for-Signal-Processing/blob/master/Maximum_likelihood.ipynb)

# %% [markdown]
# 利用 最大似然估计伯努利分布的概率

# %%
from __future__ import division
from scipy.stats import bernoulli 
import numpy as np

p_true=1/2 # this is the value we will try to estimate from the observed data
fp=bernoulli(p_true)
def sample(n=10):
    'simulate coin flipping'
    return fp.rvs(n)# flip it n times

xs = sample(100) # generate some samples
fp.cdf(x)
# Out:
# array([ 0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,
#         0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,
#         0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,
#         0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,
#         0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,
#         0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,
#         0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,
#         0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,
#         0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,  0.5,
#         1. ])

# %%
import sympy
from sympy.abc import x, z
sympy.init_printing()
p=sympy.symbols('p',positive=True)
L=p**x*(1-p)**(1-x)
J=np.prod([L.subs(x,i) for i in xs]) # objective function to maximize
J
# Out:
#  59         41
# p  ⋅(-p + 1)

# %%
logJ=sympy.expand_log(sympy.log(J))
sol=sympy.solve(sympy.diff(logJ,p),p)[0]
sol
# Out:
#  59
# ───
# 100

# %%
x=linspace(0,1,100)
plot(x,map(sympy.lambdify(p,logJ,'numpy'),x))
plot(sol,logJ.subs(p,sol),'o',p_true,logJ.subs(p,p_true),'s')
xlabel('$p$',fontsize=18)
ylabel('Likelihood',fontsize=18)
title('Estimate not equal to true value',fontsize=18)
# Out:
# /usr/lib/python2.7/dist-packages/numpy/__init__.py:1: RuntimeWarning: divide by zero encountered in log
#   """

# %%
sympy.lambdify(p,logJ,'numpy')

# %%
sol
# Out:
#  59
# ───
# 100

# %%
map(sympy.lambdify(p,logJ,'numpy'),x)
# Out:
# /usr/lib/python2.7/dist-packages/numpy/__init__.py:1: RuntimeWarning: divide by zero encountered in log
#   """
# [-inf, -271.528318388, -231.053151242, -207.555584132, -191.011665152, -178.28
# 0062107, -167.96159711, -159.30995456, -151.879694287, -145.383538467, -139.62
# 5373368, -134.465354525, -129.800259811, -125.551733777, -121.65890105, -118.0
# 73534396, -114.756785482, -111.676908576, -108.807635956, -106.126993221, -103
# .616418923, -101.260099294, -99.0444579693, -96.9577593219, -94.9897963679, -9
# 3.1316425249, -91.3754521831, -89.7142990395, -88.1420439544, -86.6532261202,
# -85.2429728069, -83.9069240366, -82.6411693532, -81.4421944639, -80.3068359954
# , -79.2322429678, -78.2158438625, -77.2553183806, -76.3485731585, -75.49372084
# 07, -74.6890620206, -73.9330696455, -73.2243755535, -72.5617588674, -71.944136
# 0178, -71.3705522079, -70.840174165, -70.3522840507, -69.9062744282, -69.50164
# 42024, -69.1379954707, -68.8150312355, -68.532553947, -68.2904648578, -68.0887
# 641856, -67.9275520941, -67.8070305166, -67.7275058616, -67.6893926563, -67.69
# 32182044, -67.739628351, -67.8293944785, -67.9634218774, -68.1427596797, -68.3
# 686125742, -68.6423545804, -68.9655452138, -69.3399484546, -69.7675550242, -70
# .2506085941, -70.7916367031, -71.3934873508, -72.0593724853, -72.7929199268, -
# 73.5982356948, -74.4799792706, -75.4434550835, -76.4947245364, -77.6407442921,
#  -78.8895385022, -80.2504154219, -81.734242814, -83.3538023186, -85.1242515416
# , -87.0637356365, -89.1942103663, -91.5425708786, -94.1422333715, -97.03540677
# 45, -100.276450387, -103.937006793, -108.11417092, -112.944142856, -118.626476
# 679, -125.47063845, -133.995179603, -145.172337881, -161.185002879, -188.99890
# 3772, -inf]
